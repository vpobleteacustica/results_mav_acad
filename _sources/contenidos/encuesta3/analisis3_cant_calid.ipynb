# %%
# %matplotlib inline
from utils import *
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# #  Opiniones de los académicos sobre la <span style="color:#AC1212">*cantidad*</span> de los recursos de apoyo

# %% [markdown]
# ##  Las respuestas se concentran en aspectos referidos a <span style="color:#AC1212">*infraestructura*</span> y <span style="color:#AC1212">*servicios de apoyo*</span> a la docencia para el MAV

# %% [markdown]
# ### Las opiniones se basaron en la siguiente escala:
# Escala  | Opinión
# :--- |:---
# 1  | Muy insuficiente
# 2  | Insuficiente
# 3  | Regular
# 4  | Adecuada
# 5  | Óptima
# NA | No aplica/no sabe

# %% [markdown]
# ### Opiniones sobre la evaluación de la  <span style="color:#AC1212">*cantidad*</span>

# %%
path_file_sorted    = 'acad.xlsx'
opinion_quantity(path_file_sorted)
# Out:
# <div>                            <div id="183a5df0-3222-439a-9a5f-e77d16a2d415" class="plotly-graph-div" style="height:270px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("183a5df0-3222-439a-9a5f-e77d16a2d415")) {                    Plotly.newPlot(                        "183a5df0-3222-439a-9a5f-e77d16a2d415",                        [{"name": "Muy insuficiente", "orientation": "h", "type": "bar", "x": [], "y": ["Colecci\u00f3n tem\u00e1tica relevante <br> de la Biblioteca "]}, {"name": "Insuficiente: 10%", "orientation": "h", "type": "bar", "x": [10.0], "y": ["Colecci\u00f3n tem\u00e1tica relevante <br> de la Biblioteca "]}, {"name": "Regular: 9.1%", "orientation": "h", "type": "bar", "x": [], "y": ["Colecci\u00f3n tem\u00e1tica relevante <br> de la Biblioteca "]}, {"name": "Adecuada: 30%", 
# ...

# %%
opinion_journals(path_file_sorted)
# Out:
# <div>                            <div id="583a155f-5e3c-497a-85cd-8372cb33e1b5" class="plotly-graph-div" style="height:270px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("583a155f-5e3c-497a-85cd-8372cb33e1b5")) {                    Plotly.newPlot(                        "583a155f-5e3c-497a-85cd-8372cb33e1b5",                        [{"name": "Muy insuficiente", "orientation": "h", "type": "bar", "x": [], "y": ["Colecci\u00f3n de revistas relevantes <br> para el Programa "]}, {"name": "Insuficiente: 11.1%", "orientation": "h", "type": "bar", "x": [11.1], "y": ["Colecci\u00f3n de revistas relevantes <br> para el Programa "]}, {"name": "Regular: 11.1%", "orientation": "h", "type": "bar", "x": [], "y": ["Colecci\u00f3n de revistas relevantes <br> para el Programa "]}, {"name": "Adecuada: 33.3%"
# ...

# %%
opinion_data_sets(path_file_sorted)
# Out:
# <div>                            <div id="e35936be-c896-44e3-95e3-a6c276fc29ab" class="plotly-graph-div" style="height:270px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e35936be-c896-44e3-95e3-a6c276fc29ab")) {                    Plotly.newPlot(                        "e35936be-c896-44e3-95e3-a6c276fc29ab",                        [{"name": "Muy insuficiente", "orientation": "h", "type": "bar", "x": [], "y": ["Bases de datos bibliogr\u00e1ficas "]}, {"name": "Insuficiente: 10%", "orientation": "h", "type": "bar", "x": [10.0], "y": ["Bases de datos bibliogr\u00e1ficas "]}, {"name": "Regular: 9.1%", "orientation": "h", "type": "bar", "x": [], "y": ["Bases de datos bibliogr\u00e1ficas "]}, {"name": "Adecuada: 40%", "orientation": "h", "type": "bar", "x": [40.0], "y": ["Bases de datos bibliogr
# ...

# %%
opinion_labs(path_file_sorted)
# Out:
# <div>                            <div id="0dcc3519-d569-4b59-8185-d41e6e2df407" class="plotly-graph-div" style="height:270px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0dcc3519-d569-4b59-8185-d41e6e2df407")) {                    Plotly.newPlot(                        "0dcc3519-d569-4b59-8185-d41e6e2df407",                        [{"name": "Muy insuficiente: 9.1%", "orientation": "h", "type": "bar", "x": [9.1], "y": ["Laboratorios disponibles <br> para el Programa "]}, {"name": "Insuficiente: 10%", "orientation": "h", "type": "bar", "x": [], "y": ["Laboratorios disponibles <br> para el Programa "]}, {"name": "Regular: 18.2%", "orientation": "h", "type": "bar", "x": [18.2], "y": ["Laboratorios disponibles <br> para el Programa "]}, {"name": "Adecuada: 27.3%", "orientation": "h", "type": "b
# ...

# %%
opinion_equipment(path_file_sorted)
# Out:
# <div>                            <div id="cdfed75d-61e2-486f-a2a3-f9d90019293a" class="plotly-graph-div" style="height:270px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdfed75d-61e2-486f-a2a3-f9d90019293a")) {                    Plotly.newPlot(                        "cdfed75d-61e2-486f-a2a3-f9d90019293a",                        [{"name": "Muy insuficiente: 9.1%", "orientation": "h", "type": "bar", "x": [], "y": ["Equipamiento mayor <br> del Programa "]}, {"name": "Insuficiente: 10%", "orientation": "h", "type": "bar", "x": [10.0], "y": ["Equipamiento mayor <br> del Programa "]}, {"name": "Regular: 10%", "orientation": "h", "type": "bar", "x": [10.0], "y": ["Equipamiento mayor <br> del Programa "]}, {"name": "Adecuada: 40%", "orientation": "h", "type": "bar", "x": [40.0], "y": ["Equipami
# ...

# %%
opinion_offices(path_file_sorted)
# Out:
# <div>                            <div id="ff95d5aa-8600-4a78-8329-a1548172ca4a" class="plotly-graph-div" style="height:270px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff95d5aa-8600-4a78-8329-a1548172ca4a")) {                    Plotly.newPlot(                        "ff95d5aa-8600-4a78-8329-a1548172ca4a",                        [{"name": "Muy insuficiente: 9.1%", "orientation": "h", "type": "bar", "x": [], "y": ["Oficinas e instalaciones <br> para acad\u00e9micos "]}, {"name": "Insuficiente: 10%", "orientation": "h", "type": "bar", "x": [10.0], "y": ["Oficinas e instalaciones <br> para acad\u00e9micos "]}, {"name": "Regular: 10%", "orientation": "h", "type": "bar", "x": [10.0], "y": ["Oficinas e instalaciones <br> para acad\u00e9micos "]}, {"name": "Adecuada: 30%", "orientation": "h", "
# ...

# %%
opinion_computers(path_file_sorted)
# Out:
# <div>                            <div id="50a4e640-9bc4-4dcc-a147-e39faea9e646" class="plotly-graph-div" style="height:270px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50a4e640-9bc4-4dcc-a147-e39faea9e646")) {                    Plotly.newPlot(                        "50a4e640-9bc4-4dcc-a147-e39faea9e646",                        [{"name": "Muy insuficiente: 9.1%", "orientation": "h", "type": "bar", "x": [], "y": ["Computadores <br> para acad\u00e9micos "]}, {"name": "Insuficiente: 10%", "orientation": "h", "type": "bar", "x": [10.0], "y": ["Computadores <br> para acad\u00e9micos "]}, {"name": "Regular: 10%", "orientation": "h", "type": "bar", "x": [10.0], "y": ["Computadores <br> para acad\u00e9micos "]}, {"name": "Adecuada: 30%", "orientation": "h", "type": "bar", "x": [30.0], "y": ["Co
# ...

# %%
opinion_soft(path_file_sorted)
# Out:
# <div>                            <div id="4281257f-a569-4d35-a859-1d87749ac044" class="plotly-graph-div" style="height:270px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4281257f-a569-4d35-a859-1d87749ac044")) {                    Plotly.newPlot(                        "4281257f-a569-4d35-a859-1d87749ac044",                        [{"name": "Muy insuficiente: 9.1%", "orientation": "h", "type": "bar", "x": [], "y": ["Software <br> para acad\u00e9micos "]}, {"name": "Insuficiente: 10%", "orientation": "h", "type": "bar", "x": [10.0], "y": ["Software <br> para acad\u00e9micos "]}, {"name": "Regular: 20%", "orientation": "h", "type": "bar", "x": [20.0], "y": ["Software <br> para acad\u00e9micos "]}, {"name": "Adecuada: 30%", "orientation": "h", "type": "bar", "x": [30.0], "y": ["Software <br> 
# ...

# %%
opinion_printers(path_file_sorted)
# Out:
# <div>                            <div id="d73a94d1-94ad-42fc-aa9f-2c6692a00f1f" class="plotly-graph-div" style="height:270px; width:750px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d73a94d1-94ad-42fc-aa9f-2c6692a00f1f")) {                    Plotly.newPlot(                        "d73a94d1-94ad-42fc-aa9f-2c6692a00f1f",                        [{"name": "Muy insuficiente: 9.1%", "orientation": "h", "type": "bar", "x": [], "y": ["Impresoras <br> para acad\u00e9micos "]}, {"name": "Insuficiente: 10%", "orientation": "h", "type": "bar", "x": [], "y": ["Impresoras <br> para acad\u00e9micos "]}, {"name": "Regular: 12.5%", "orientation": "h", "type": "bar", "x": [12.5], "y": ["Impresoras <br> para acad\u00e9micos "]}, {"name": "Adecuada: 37.5%", "orientation": "h", "type": "bar", "x": [37.5], "y": ["Impresor
# ...
